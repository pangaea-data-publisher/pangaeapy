# %% [markdown]
# # Basic pangaeapy example: plotting with pandas

# %%
from pangaeapy import PanDataSet

# %%
ds=PanDataSet(900968)

# %% [markdown]
# Before we start we need to now how the columns are named, pangaeapy uses the short names of a given parameter to label each column.

# %%
ds.data.columns
# Out:
# Index(['Depth', 'Age', 'TOC', 'TN', 'CaCO3', 'δ15N', 'δ15N std dev',
#        'δ13C carb', 'δ13C std dev', 'δ18O carb', 'δ18O std dev', 'Latitude',
#        'Longitude', 'Elevation', 'Event', 'Date/Time'],
#       dtype='object')

# %% [markdown]
# Now plotting is easy using the standard pandas plot method:

# %%
ds.data.plot(x='Age', y='CaCO3')

# %%
ds.citation
# Out:
# 'Burdanowitz, Nicole; Gaye, Birgit; Hilbig, Lea; Lahajnar, Niko; Lückge, Andreas; Rixen, Tim; Emeis, Kay-Christian (2019): Stable isotope composition of sediment core SO90_63KA. PANGAEA, https://doi.org/10.1594/PANGAEA.900968, In supplement to: Burdanowitz, N et al. (2019): Holocene monsoon and sea level-related changes of sedimentation in the northeastern Arabian Sea. Deep Sea Research Part II: Topical Studies in Oceanography, https://doi.org/10.1016/j.dsr2.2019.03.003'
